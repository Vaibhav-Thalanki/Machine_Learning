# %%
import pandas as pd
import numpy as np

# %%
#churn modelling - if customer is staying or leaving for competitor
df = pd.read_csv('D:\codes_programming\py files\Datasets\Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female  42.0
# 1             2    15647311       Hill          225     Spain  Female  41.0
# 2             3    15619304       Onio          629    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850       NaN  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
df.isnull().any() #null values iN geography, gender,age,balance
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography           True
# Gender              True
# Age                 True
# Tenure             False
# Balance             True
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.shape
# Out:
# (10000, 14)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        9999 non-null   object
#  5   Gender           9999 non-null   object
#  6   Age              9999 non-null   float64
#  7   Tenure           10000 non-null  int64
#  8   Balance          9999 non-null   float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId  CreditScore          Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.00000  9999.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.48290    38.924892      5.012800
# std     2886.89568  7.193619e+04     96.72014    10.486670      2.892174
# min        1.00000  1.556570e+07    225.00000    18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.00000    32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.00000    37.000000      5.000000
# 75%     7500.25000  1.575323e+07    717.25000    44.000000      7.000000
# max    10000.00000  1.581569e+07    850.00000    92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    9999.000000   10000.000000  10000.00000    10000.000000
# mean    76483.536070       1.530200      0.70550        0.515100
# std     62400.186375       0.581654      0.45584        0.499797
# ...

# %%
df.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False       True   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
#replace null with either mode, median or mean
#use mode when we have categories, here geography and gender
#for small range numerical data use mean, here age
#for large range numerical data use median, here balance

# %%
df['Geography'].fillna(df['Geography'].mode()[0],inplace=True) #inplace=true makes changes permanent

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True) #inplace=true makes changes permanent

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True) #inplace=true makes changes permanent

# %%
df['Balance'].fillna(df['Balance'].median(),inplace=True) #inplace=true makes changes permanent

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female  42.0
# 1             2    15647311       Hill          225     Spain  Female  41.0
# 2             3    15619304       Onio          629    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850    France  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
df.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#convert textual data to numerical using label encoding
#label encoding works in alphabetical order so France will be 0,germany will be 1, spain will be 2
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Geography'] = le.fit_transform(df['Geography'])
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619          0       0  42.0
# 1             2    15647311       Hill          225          2       0  41.0
# 2             3    15619304       Onio          629          0       0  42.0
# 3             4    15701354       Boni          699          0       0  39.0
# 4             5    15737888   Mitchell          850          0       0  43.0
# ...         ...         ...        ...          ...        ...     ...   ...
# 9995       9996    15606229   Obijiaku          771          0       1  39.0
# 9996       9997    15569892  Johnstone          516          0       1  35.0
# 9997       9998    15584532        Liu          709          0       0  36.0
# 9998       9999    15682355  Sabbatini          772          1       1  42.0
# 9999      10000    15628319     Walker          792          0       0  28.0
#
# ...

# %%
#in gender is easy, 0-false-female 1-true-male
#but in geography, we have 0,1,2 to represent different categories, not numerical dats
# so convert into categorical values using one hot encoder
#it'll be converted to 3 columnsacting like a truth table but since simultaneous isnt possible it'll be 100 010 001

# %%
#divide data into dependant and independant
#use values to convert to numpy arrays
x=df.iloc[:,3:13].values
y=df.iloc[:,13:].values

# %%
x
# Out:
# array([[6.1900000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [2.2500000e+02, 2.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [6.2900000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [7.0900000e+02, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [7.7200000e+02, 1.0000000e+00, 1.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [7.9200000e+02, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
#onehot encoding on geography
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()
z= one.fit_transform(x[:,1:2]).toarray()

# %%
z
# Out:
# array([[1., 0., 0.],
#        [0., 0., 1.],
#        [1., 0., 0.],
#        ...,
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.]])

# %%
x.shape
# Out:
# (10000, 10)

# %%
x = np.delete(x,1,axis=1) #axis 1 means column
x.shape
# Out:
# (10000, 9)

# %%
#concatenate z to x
x = np.concatenate((z,x),axis=1)
x
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]])

# %%
x.shape
# Out:
# (10000, 12)

# %%
#splitting train-test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)
#0.2 means 20% data will be test
print(x_train.shape)
print(x_test.shape)
# Out:
# (8000, 12)
# (2000, 12)

# %%
#feature scaling
#standard scaling = (x-mean)/std. dev
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-1.0148604 , -0.5698444 ,  1.74367544, ...,  0.64259497,
#         -1.03227043,  1.10643166],
#        [-1.0148604 ,  1.75486502, -0.57350122, ...,  0.64259497,
#          0.9687384 , -0.74866447],
#        [ 0.98535719, -0.5698444 , -0.57350122, ...,  0.64259497,
#         -1.03227043,  1.48533467],
#        ...,
#        [ 0.98535719, -0.5698444 , -0.57350122, ...,  0.64259497,
#         -1.03227043,  1.41231994],
#        [-1.0148604 , -0.5698444 ,  1.74367544, ...,  0.64259497,
#          0.9687384 ,  0.84432121],
#        [-1.0148604 ,  1.75486502, -0.57350122, ...,  0.64259497,
#         -1.03227043,  0.32472465]])
